# %% [markdown]
# # Business Problem
# #### prepare a project to show home owners how to price homes theyre having built based on data already known of similar homes. (CMA)

# %%
## Import libraries ##
import pandas as pd
import numpy as np
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.dummy import DummyRegressor
import statsmodels
from statsmodels.formula.api import ols

# %%
#open file
df=pd.read_csv('data/kc_house_data.csv',  index_col='id')
df
# Out:
#                   date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 7129300520  10/13/2014  221900.0         3       1.00         1180      5650
# 6414100192   12/9/2014  538000.0         3       2.25         2570      7242
# 5631500400   2/25/2015  180000.0         2       1.00          770     10000
# 2487200875   12/9/2014  604000.0         4       3.00         1960      5000
# 1954400510   2/18/2015  510000.0         3       2.00         1680      8080
# ...                ...       ...       ...        ...          ...       ...
# 263000018    5/21/2014  360000.0         3       2.50         1530      1131
# 6600060120   2/23/2015  400000.0         4       2.50         2310      5813
# 1523300141   6/23/2014  402101.0         2       0.75         1020      1350
# 291310100    1/16/2015  400000.0         3       2.50         1600      2388
# 1523300157  10/15/2014  325000.0         2       0.75         1020      1076
#
# ...

# %%
#checking to see whats correlated at a point of .7 or above
df.corr()
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.308787   0.525906     0.701917  0.089876  0.256804
# bedrooms       0.308787  1.000000   0.514508     0.578212  0.032471  0.177944
# bathrooms      0.525906  0.514508   1.000000     0.755758  0.088373  0.502582
# sqft_living    0.701917  0.578212   0.755758     1.000000  0.173453  0.353953
# sqft_lot       0.089876  0.032471   0.088373     0.173453  1.000000 -0.004814
# floors         0.256804  0.177944   0.502582     0.353953 -0.004814  1.000000
# sqft_above     0.605368  0.479386   0.686668     0.876448  0.184139  0.523989
# yr_built       0.053953  0.155670   0.507173     0.318152  0.052946  0.489193
# yr_renovated   0.129599  0.018495   0.051050     0.055660  0.004513  0.003535
# zipcode       -0.053402 -0.154092  -0.204786    -0.199802 -0.129586 -0.059541
# lat            0.306692 -0.009951   0.024280     0.052155 -0.085514  0.049239
# ...

# %% [markdown]
# sqft variables are all highly correlated

# %%
df.drop(['date','zipcode','waterfront','view','long','lat','sqft_above','sqft_basement','sqft_living15', 'sqft_lot15'], axis=1, inplace=True)

# %%
df.head()
# Out:
#                price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# id
# 7129300520  221900.0         3       1.00         1180      5650     1.0
# 6414100192  538000.0         3       2.25         2570      7242     2.0
# 5631500400  180000.0         2       1.00          770     10000     1.0
# 2487200875  604000.0         4       3.00         1960      5000     1.0
# 1954400510  510000.0         3       2.00         1680      8080     1.0
#
#             condition          grade  yr_built  yr_renovated
# id
# 7129300520    Average      7 Average      1955           0.0
# 6414100192    Average      7 Average      1951        1991.0
# 5631500400    Average  6 Low Average      1933           NaN
# 2487200875  Very Good      7 Average      1965           0.0
# 1954400510    Average         8 Good      1987           0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21597 entries, 7129300520 to 1523300157
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         21597 non-null  float64
#  1   bedrooms      21597 non-null  int64
#  2   bathrooms     21597 non-null  float64
#  3   sqft_living   21597 non-null  int64
#  4   sqft_lot      21597 non-null  int64
#  5   floors        21597 non-null  float64
#  6   condition     21597 non-null  object
#  7   grade         21597 non-null  object
#  8   yr_built      21597 non-null  int64
#  9   yr_renovated  17755 non-null  float64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 1.8+ MB

# %%
df
# Out:
#                price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# id
# 7129300520  221900.0         3       1.00         1180      5650     1.0
# 6414100192  538000.0         3       2.25         2570      7242     2.0
# 5631500400  180000.0         2       1.00          770     10000     1.0
# 2487200875  604000.0         4       3.00         1960      5000     1.0
# 1954400510  510000.0         3       2.00         1680      8080     1.0
# ...              ...       ...        ...          ...       ...     ...
# 263000018   360000.0         3       2.50         1530      1131     3.0
# 6600060120  400000.0         4       2.50         2310      5813     2.0
# 1523300141  402101.0         2       0.75         1020      1350     2.0
# 291310100   400000.0         3       2.50         1600      2388     2.0
# 1523300157  325000.0         2       0.75         1020      1076     2.0
#
#             condition          grade  yr_built  yr_renovated
# id
# ...

# %%
X=df.drop('price',axis=1) 
Y=df['price']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state=42)

# %%
X_train.shape
# Out:
# (16197, 9)

# %%
#creating dummy regressor thats the mean of Y(price)
dummy_regr = DummyRegressor(strategy="mean")
dummy_regr.fit(X_train, Y_train)
DummyRegressor()
dummy_regr.predict(X_train)
# Out:
# array([541284.46156696, 541284.46156696, 541284.46156696, ...,
#        541284.46156696, 541284.46156696, 541284.46156696])

# %%
dummy_regr.score(X_train, Y_train)
# Out:
# 0.0

# %%
#creating inferential model
formula= 'price~sqft_lot'
mod = ols(formula, df).fit()
mod_summ = mod.summary()

mod_summ
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     175.9
# Date:                Tue, 16 Nov 2021   Prob (F-statistic):           5.57e-40
# Time:                        16:52:38   Log-Likelihood:            -3.0730e+05
# No. Observations:               21597   AIC:                         6.146e+05
# Df Residuals:                   21595   BIC:                         6.146e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   5.283e+05   2650.075    199.337      0.000    5.23e+05    5.33e+05
# ...

# %%
#creating first simple model
all_formula= 'price~sqft_lot + bedrooms + bathrooms + floors + yr_built + sqft_living '
all_mod = ols(all_formula, df).fit()
all_mod_summ = all_mod.summary()

all_mod_summ
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.556
# Model:                            OLS   Adj. R-squared:                  0.556
# Method:                 Least Squares   F-statistic:                     4511.
# Date:                Tue, 16 Nov 2021   Prob (F-statistic):               0.00
# Time:                        16:11:24   Log-Likelihood:            -2.9862e+05
# No. Observations:               21597   AIC:                         5.972e+05
# Df Residuals:                   21590   BIC:                         5.973e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    6.559e+06   1.35e+05     48.643      0.000     6.3e+06    6.82e+06
# ...

# %%
df.head()
# Out:
#                price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# id
# 7129300520  221900.0         3       1.00         1180      5650     1.0
# 6414100192  538000.0         3       2.25         2570      7242     2.0
# 5631500400  180000.0         2       1.00          770     10000     1.0
# 2487200875  604000.0         4       3.00         1960      5000     1.0
# 1954400510  510000.0         3       2.00         1680      8080     1.0
#
#             condition          grade  yr_built  yr_renovated
# id
# 7129300520    Average      7 Average      1955           0.0
# 6414100192    Average      7 Average      1951        1991.0
# 5631500400    Average  6 Low Average      1933           NaN
# 2487200875  Very Good      7 Average      1965           0.0
# 1954400510    Average         8 Good      1987           0.0

# %%
df.corr()
# Out:
#                  price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price         1.000000  0.308787   0.525906     0.701917  0.089876  0.256804
# bedrooms      0.308787  1.000000   0.514508     0.578212  0.032471  0.177944
# bathrooms     0.525906  0.514508   1.000000     0.755758  0.088373  0.502582
# sqft_living   0.701917  0.578212   0.755758     1.000000  0.173453  0.353953
# sqft_lot      0.089876  0.032471   0.088373     0.173453  1.000000 -0.004814
# floors        0.256804  0.177944   0.502582     0.353953 -0.004814  1.000000
# yr_built      0.053953  0.155670   0.507173     0.318152  0.052946  0.489193
# yr_renovated  0.129599  0.018495   0.051050     0.055660  0.004513  0.003535
#
#               yr_built  yr_renovated
# price         0.053953      0.129599
# bedrooms      0.155670      0.018495
# bathrooms     0.507173      0.051050
# sqft_living   0.318152      0.055660
# sqft_lot      0.052946      0.004513
# floors        0.489193      0.003535
# ...

# %%
ax.bar

# %%
df['price'].sort_values(ascending=False)[:60]
# Out:
# id
# 6762700020    7700000.0
# 9808700762    7060000.0
# 9208900037    6890000.0
# 2470100110    5570000.0
# 8907500070    5350000.0
# 7558700030    5300000.0
# 1247600105    5110000.0
# 1924059029    4670000.0
# 7738500731    4500000.0
# 3835500195    4490000.0
# 6065300370    4210000.0
# 6447300265    4000000.0
# 8106100105    3850000.0
# 2303900100    3800000.0
# 853200010     3800000.0
# 7397300170    3710000.0
# 4389201095    3650000.0
# 4217402115    3650000.0
# 3625049042    3640000.0
# 2425049063    3640000.0
# 4114601570    3600000.0
# 9253900271    3570000.0
# 2525049148    3420000.0
# 1118000320    3400000.0
# 9362000040    3400000.0
# 3126059023    3400000.0
# 9808100150    3350000.0
# 3625059152    3300000.0
# 6072800246    3300000.0
# 3625059043    3300000.0
# 1346300150    3300000.0
# 7524900003    3280000.0
# 251500080     3200000.0
# 1068000375    3200000.0
# 624069108     3200000.0
# 7159200005    3200000.0
# 8964800890    3200000.0
# 3025059124    3170000.0
# ...

# %%
fig, axes = plt.subplots(ncols=3, nrows=2, figsize=(12, 8))
fig.set_tight_layout(True)

xcont = df.select_dtypes(('int64', 'float64')).columns.drop([ 'yr_built', 'price', 'yr_renovated'])


for xcol, ax in zip(xcont, axes.flatten()):
    ax.scatter(df[xcol], df['price'], alpha=0.2)
    ax.set_xlabel(xcol)
    ax.set_ylabel("price")

# %%
plt.hist(df['price'],bins=50)
# Out:
# (array([1.675e+03, 6.360e+03, 5.475e+03, 3.498e+03, 2.045e+03, 1.011e+03,
#         4.120e+02, 3.120e+02, 2.230e+02, 1.600e+02, 1.080e+02, 7.800e+01,
#         4.800e+01, 3.000e+01, 3.400e+01, 3.200e+01, 1.700e+01, 1.200e+01,
#         1.500e+01, 1.400e+01, 6.000e+00, 1.000e+01, 1.000e+00, 6.000e+00,
#         3.000e+00, 1.000e+00, 0.000e+00, 1.000e+00, 1.000e+00, 1.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 2.000e+00, 0.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 1.000e+00, 1.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00]),
#  array([  78000.,  230440.,  382880.,  535320.,  687760.,  840200.,
#          992640., 1145080., 1297520., 1449960., 1602400., 1754840.,
#         1907280., 2059720., 2212160., 2364600., 2517040., 2669480.,
#         2821920., 2974360., 3126800., 3279240., 3431680., 3584120.,
#         3736560., 3889000., 4041440., 4193880., 4346320., 4498760.,
# ...

# %%
plt.boxplot(df['price'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fc4cbc511c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fc4cbc51880>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fc4cbc41e20>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fc4cbc51f70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fc4cbc5c310>],
#  'means': []}

# %% [markdown]
# completely unstandardized distribution
